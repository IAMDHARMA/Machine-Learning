# %%
import pandas as pd
from sqlalchemy import create_engine

# Create SQLAlchemy connection (change username, password, host, dbname)
engine = create_engine("mysql+pymysql://root:dharma@localhost:3306/supply_chain_management_system")

# Read SQL query from file
with open("C:/Users/Dharm/AppData/Roaming/DBeaverData/workspace6/General/Scripts/Script-1.sql", "r") as file:
    sql_query = file.read()

sql_query_1="select * from Warehouses;"

# Execute query and load into DataFrame
df = pd.read_sql_query(sql_query, engine)
df
# Out:
#                   supplierName        contactName               phone  \
# 0                    Stark Inc    Kevin Rodriguez        257-276-9787
# 1                  Klein-Klein      Amanda Miller        964.778.5271
# 2                 Parker Group        James Young        983.582.7414
# 3                   Watson Inc    Andrew Anderson   888-216-1192x2701
# 4                  Howard-Boyd   Elizabeth Nelson       (313)213-9073
# 5   Ramos, Campbell and Vargas    Samantha Miller        786-929-0557
# 6                Kennedy Group   Stephanie Flores   939.451.6824x7066
# 7                   Walton Inc     David Gonzalez   (902)375-3644x278
# 8             Douglas and Sons    Daniel Anderson    192.086.6247x080
# 9                   Nguyen PLC     Jennifer Smith        241-603-2514
# 10                Gonzalez LLC      Rachel Carter        814.487.9680
# 11                  Nelson LLC      Thomas Garcia   630-012-1462x9185
# ...

# %%
sql_query_1="select * from Warehouses;"
sql_data=pd.read_sql(sql_query_1,engine)
sql_data
# Out:
#     WarehouseID             WarehouseName                             Location
# 0             1       Lake John Warehouse      East Zacharyport, United States
# 1             2   West Brittany Warehouse           East Amanda, United States
# 2             3       New Sarah Warehouse          Port Tiffany, United States
# 3             4    Port Lindsay Warehouse             West Ryan, United States
# 4             5      Port Tanya Warehouse      Port Crystalfort, United States
# 5             6     Port Donald Warehouse           Port Rodney, United States
# 6             7    Port Matthew Warehouse          South Victor, United States
# 7             8     Lake Andrew Warehouse           Port Daniel, United States
# 8             9     North Scott Warehouse           Lake Amanda, United States
# 9            10     South Brian Warehouse      North Crystalton, United States
# 10           11      Lake Bryan Warehouse             West Dana, United States
# ...
